# %%
import pandas as pd
from datetime import datetime
df = pd.read_csv('faang-10.csv')

#df = pd.read_csv('stock-empresas10.csv')

#df=df.set_index('name')

print('Tamaño del la muestra {}'.format(df['Open'].count()))

#delimitar 2020
df['Date']=pd.to_datetime(df['Date'])

#delimitar 2021 hasta el 12 de marzo

df
# Out:
# Tamaño del la muestra 654
#     web-scraper-order                              web-scraper-start-url  \
# 0     1620589824-1017  https://finance.yahoo.com/quote/AAPL/history?p...
# 1     1620589835-1287  https://finance.yahoo.com/quote/FB/history?per...
# 2      1620589819-928  https://finance.yahoo.com/quote/NFLX/history?p...
# 3      1620589819-817  https://finance.yahoo.com/quote/NFLX/history?p...
# 4     1620589824-1097  https://finance.yahoo.com/quote/AAPL/history?p...
# ..                ...                                                ...
# 649    1620589814-744  https://finance.yahoo.com/quote/GOOG/history?p...
# 650   1620589824-1075  https://finance.yahoo.com/quote/AAPL/history?p...
# 651   1620589835-1236  https://finance.yahoo.com/quote/FB/history?per...
# 652    1620589819-917  https://finance.yahoo.com/quote/NFLX/history?p...
# 653   1620589830-1184  https://finance.yahoo.com/quote/AMZN/history?p...
#
#           Date             Open    High     Low  Close*  \
# ...

# %%
data=df.loc[df["name"]=='Facebook, Inc. (FB)'].replace(',', '', regex=True)
min=data.loc[data["Date"]==data["Date"].min()].replace(',', '', regex=True)
max=data.loc[data["Date"]==data["Date"].max()].replace(',', '', regex=True)
print('\nFacebook abrió con {} en el  {} cerró con {} en el {} con un crecimiento del {}% '.
      format(min['Open'].iloc[0],
             min['Date'].iloc[0],
             max['Close*'].iloc[0],
             max['Date'].iloc[0],
             float(max['Close*'].iloc[0])*100/float(min['Open'].iloc[0])))
# Out:
# Facebook abrió con 28.89 en el  2012-06-01 00:00:00 cerró con 319.08 en el 2021-05-07 00:00:00 con un crecimiento del 1104.4652128764278%

# %%
min['Date'].date_range(start='1/1/2018', periods=5, freq='M')

# %%
max

# %%
data=df.loc[df["name"]=='Apple Inc. (AAPL)'].replace(',', '', regex=True)
min=data.loc[data["Date"]==data["Date"].min()].replace(',', '', regex=True)
max=data.loc[data["Date"]==data["Date"].max()].replace(',', '', regex=True)

print('\nFacebook abrió con {} en el  {} cerró con {} en el {} con un crecimiento del {}% '.
      format(min['Open'].iloc[0],
             min['Date'].iloc[0],
             max['Close*'].iloc[1],
             max['Date'].iloc[1],
             float(max['Close*'].iloc[1])*100/float(min['Open'].iloc[0])))
# Out:
# Facebook abrió con 11.63 en el  2011-01-01 00:00:00 cerró con 130.21 en el 2021-05-07 00:00:00 con un crecimiento del 1119.6044711951847%

# %%
data=df.loc[df["Date"]==df['Date'].min(),'Open'].replace(',', '', regex=True).astype(float).to_frame() 
data['Close']=df.loc[df["Date"]==df['Date'].max(),'Close*'].replace(',', '', regex=True).astype(float)
data['crecimiento']=data['Close']*100/data['Open']
print(df20['Date'].min())
print(data)

print('\nLa Empresa con mejor rendimiento en 2020 fue {} con un crecimiento de {}%'.
      format(data['2020'].idxmax(), round(data['2020'].max(),2)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d43da1242420> in <module>
#       1 data=df.loc[df["Date"]==df['Date'].min(),'Open'].replace(',', '', regex=True).astype(float).to_frame()
# ----> 2 data['Close']=df.loc[df["Date"]==df['Date'].max(),'Close*'].replace(',', '', regex=True).astype(float)
#       3 data['crecimiento']=data['Close']*100/data['Open']
#       4 print(df20['Date'].min())
#       5 print(data)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# ...

# %%
data['Open21']=df21.loc[df21["Date"]==df21['Date'].min(),'Open'].replace(',', '', regex=True).astype(float)
data['Close21']=df21.loc[df21["Date"]==df21['Date'].max(),'Close*'].replace(',', '', regex=True).astype(float)
data['2021']=data['Close21']*100/data['Open21']
print(df21['Date'].max())
print(df21['Date'].min())
print(data)

print('\nLa Empresa con mejor rendimiento en 2021 fue {} con un crecimiento de {}%'.
      format(data['2021'].idxmax(), round(data['2021'].max(),2)))
# Out:
# 2021-03-01 00:00:00
# 2021-02-01 00:00:00
#                          Open20  Close20         2020   Open21  Close21  \
# name
# Apple Inc. (AAPL)         11.63   132.69  1140.928633   133.75   122.15
# Netflix, Inc. (NFLX)      25.00   540.73  2162.920000   536.79   521.66
# Amazon.com, Inc. (AMZN)  181.37  3256.93  1795.737994  3242.36  3094.08
# Alphabet Inc. (GOOG)     297.13  1751.88   589.600512  1853.57  2068.63
#
#                                2021
# name
# Apple Inc. (AAPL)         91.327103
# Netflix, Inc. (NFLX)      97.181393
# Amazon.com, Inc. (AMZN)   95.426788
# Alphabet Inc. (GOOG)     111.602475
#
# La Empresa con mejor rendimiento en 2021 fue Alphabet Inc. (GOOG) con un crecimiento de 111.6%
